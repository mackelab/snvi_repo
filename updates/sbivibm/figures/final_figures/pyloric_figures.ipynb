# %%
from sbivibm.tasks import Pyloric
from sbivibm.utils import get_posterior_by_id, get_full_dataset, get_samples_by_id, get_predictive_samples_by_id
from sbi.utils import pairplot, conditional_pairplot
import torch

# %%
import random 
import numpy as np

# %%
seed = 0
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# %%
task = Pyloric()
simulator = task.get_simulator(sim_type="slurm")

# %%
# Two independent runs which are equivalent
seeded_id_run1 = "2630e300-3b4b-4087-808b-6450c158c2f7"
seeded_id_run1 = "18fd570e-9289-4928-83c9-bf89a7e77f08"

# %%
posterior = get_posterior_by_id("benchmark", seeded_id_run1)

# %% [markdown]
# ## Computing raw fraction of valids

# %%
thetas_predictives = posterior.sample((10000,))

# %%
# xs_predictives = simulator(thetas_predictives)

# %%
# torch.save(thetas_predictives, "thetas_for_predictive.pkl")
# torch.save(xs_predictives, "xs_for_predictive.pkl")

# %%
thetas_predictives = torch.load( "thetas_for_predictive.pkl")
xs_predictives = torch.load( "xs_for_predictive.pkl")

# %%
sum((xs_predictives!=-99).all(1))
# Out:
# tensor(8556)

# %%
frac_valid = sum((xs_predictives!=-99).all(1))/len(xs_predictives)
print(f"{frac_valid:.2}")
# Out:
# 0.86

# %% [markdown]
# ## Figures

# %%
samples = posterior.sample((10000000,), vi_parameters={"sampling_method_params":{"num_samples_batch": 100000}})

# %%
MEAN = samples.mean(0)
MEAN
# Out:
# tensor([ 2.6125e+02,  3.8422e+00,  3.4151e+00,  2.8728e+01,  7.8768e+00,
#          1.0370e+02,  9.4817e-03,  3.6051e-03,  1.1801e+02,  1.0507e+00,
#          6.2986e+00,  3.7093e+01,  5.5719e+00,  7.9130e+01,  3.5515e-02,
#          2.3936e-02,  3.0478e+02,  7.4433e+00,  2.9181e+00,  4.2714e+01,
#          1.6886e+00,  1.0060e+02,  3.4966e-02,  1.8026e-02, -8.7705e+00,
#         -1.4743e+01, -1.3164e+01, -9.2409e+00, -9.9842e+00, -1.5784e+01,
#         -1.0309e+01])

# %%
MAP = posterior.map(init_method=MEAN.reshape(1,-1), learning_rate=5e-4,num_iter=2000)
# Out:
# /mnt/qb/work/macke/mgloeckler90/miniconda3/envs/snvi/lib/python3.9/site-packages/sbi/inference/posteriors/base_posterior.py:913: UserWarning: This method for obtaining the MAP estimate was introduced recently (sbi v0.15.0) and has not been tested extensively yet. You might have to tune the hyperparameters, especially `num_iter` and `learning_rate`. If you experience problems, please create an issue on Github: https://github.com/mackelab/sbi/issues
#   warn(
# Optimizing MAP estimate. Iterations: 1 /
#                         2000. Performance in iteration
#                         0:
# Optimizing MAP estimate. Iterations: 2 /alized log-prob
#                         2000. Performance in iteration
#                         0:
# Optimizing MAP estimate. Iterations: 3 /alized log-prob
#                         2000. Performance in iteration
#                         0:
# Optimizing MAP estimate. Iterations: 4 /alized log-prob
#                         2000. Performance in iteration
#                         0:
# Optimizing MAP estimate. Iterations: 5 /alized log-prob
#                         2000. Performance in iteration
#                         0:
# Optimizing MAP estimate. Iterations: 6 /alized log-prob
#                         2000. Performance in iteration
#                         0:
# Optimizing MAP estimate. Iterations: 7 /alized log-prob
#                         2000. Performance in iteration
#                         0:
# Optimizing MAP estimate. Iterations: 8 /alized log-prob
#                         2000. Performance in iteration
#                         0:
# Optimizing MAP estimate. Iterations: 9 /alized log-prob
#                         2000. Performance in iteration
#                         0:
# Optimizing MAP estimate. Iterations: 10 /lized log-prob
#                         2000. Performance in iteration
#                         10:
# Optimizing MAP estimate. Iterations: 11 /lized log-prob
#                         2000. Performance in iteration
#                         10:
# Optimizing MAP estimate. Iterations: 12 /lized log-prob
#                         2000. Performance in iteration
#                         10:
# Optimizing MAP estimate. Iterations: 13 /lized log-prob
#                         2000. Performance in iteration
#                         10:
# Optimizing MAP estimate. Iterations: 14 /lized log-prob
#                         2000. Performance in iteration
#                         10:
# Optimizing MAP estimate. Iterations: 15 /lized log-prob
#                         2000. Performance in iteration
#                         10:
# Optimizing MAP estimate. Iterations: 16 /lized log-prob
#                         2000. Performance in iteration
#                         10:
# Optimizing MAP estimate. Iterations: 17 /lized log-prob
#                         2000. Performance in iteration
#                         10:
# Optimizing MAP estimate. Iterations: 18 /lized log-prob
#                         2000. Performance in iteration
#                         10:
# Optimizing MAP estimate. Iterations: 19 /lized log-prob
#                         2000. Performance in iteration
#                         10:
# Optimizing MAP estimate. Iterations: 20 /lized log-prob
#                         2000. Performance in iteration
#                         20:
# Optimizing MAP estimate. Iterations: 21 /lized log-prob
#                         2000. Performance in iteration
#                         20:
# Optimizing MAP estimate. Iterations: 22 /lized log-prob
#                         2000. Performance in iteration
#                         20:
# Optimizing MAP estimate. Iterations: 23 /lized log-prob
#                         2000. Performance in iteration
#                         20:
# Optimizing MAP estimate. Iterations: 24 /lized log-prob
#                         2000. Performance in iteration
#                         20:
# Optimizing MAP estimate. Iterations: 25 /lized log-prob
#                         2000. Performance in iteration
#                         20:
# Optimizing MAP estimate. Iterations: 26 /lized log-prob
#                         2000. Performance in iteration
#                         20:
# Optimizing MAP estimate. Iterations: 27 /lized log-prob
#                         2000. Performance in iteration
#                         20:
# Optimizing MAP estimate. Iterations: 28 /lized log-prob
#                         2000. Performance in iteration
#                         20:
# Optimizing MAP estimate. Iterations: 29 /lized log-prob
#                         2000. Performance in iteration
#                         20:
# Optimizing MAP estimate. Iterations: 30 /lized log-prob
#                         2000. Performance in iteration
#                         30:
# Optimizing MAP estimate. Iterations: 31 /lized log-prob
#                         2000. Performance in iteration
#                         30:
# Optimizing MAP estimate. Iterations: 32 /lized log-prob
#                         2000. Performance in iteration
#                         30:
# Optimizing MAP estimate. Iterations: 33 /lized log-prob
#                         2000. Performance in iteration
#                         30:
# Optimizing MAP estimate. Iterations: 34 /lized log-prob
#                         2000. Performance in iteration
#                         30:
# Optimizing MAP estimate. Iterations: 35 /lized log-prob
#                         2000. Performance in iteration
#                         30:
# Optimizing MAP estimate. Iterations: 36 /lized log-prob
#                         2000. Performance in iteration
#                         30:
# Optimizing MAP estimate. Iterations: 37 /lized log-prob
#                         2000. Performance in iteration
#                         30:
# Optimizing MAP estimate. Iterations: 38 /lized log-prob
#                         2000. Performance in iteration
#                         30:
# Optimizing MAP estimate. Iterations: 39 /lized log-prob
#                         2000. Performance in iteration
#                         30:
# Optimizing MAP estimate. Iterations: 40 /lized log-prob
#                         2000. Performance in iteration
#                         40:
# Optimizing MAP estimate. Iterations: 41 /lized log-prob
#                         2000. Performance in iteration
#                         40:
# Optimizing MAP estimate. Iterations: 42 /lized log-prob
#                         2000. Performance in iteration
#                         40:
# Optimizing MAP estimate. Iterations: 43 /lized log-prob
#                         2000. Performance in iteration
#                         40:
# Optimizing MAP estimate. Iterations: 44 /lized log-prob
#                         2000. Performance in iteration
#                         40:
# Optimizing MAP estimate. Iterations: 45 /lized log-prob
#                         2000. Performance in iteration
#                         40:
# Optimizing MAP estimate. Iterations: 46 /lized log-prob
#                         2000. Performance in iteration
#                         40:
# Optimizing MAP estimate. Iterations: 47 /lized log-prob
#                         2000. Performance in iteration
#                         40:
# Optimizing MAP estimate. Iterations: 48 /lized log-prob
#                         2000. Performance in iteration
#                         40:
# Optimizing MAP estimate. Iterations: 49 /lized log-prob
#                         2000. Performance in iteration
#                         40:
# Optimizing MAP estimate. Iterations: 50 /lized log-prob
#                         2000. Performance in iteration
#                         50:
# Optimizing MAP estimate. Iterations: 51 /lized log-prob
#                         2000. Performance in iteration
#                         50:
# Optimizing MAP estimate. Iterations: 52 /lized log-prob
#                         2000. Performance in iteration
#                         50:
# Optimizing MAP estimate. Iterations: 53 /lized log-prob
#                         2000. Performance in iteration
#                         50:
# Optimizing MAP estimate. Iterations: 54 /lized log-prob
#                         2000. Performance in iteration
#                         50:
# Optimizing MAP estimate. Iterations: 55 /lized log-prob
#                         2000. Performance in iteration
#                         50:
# Optimizing MAP estimate. Iterations: 56 /lized log-prob
#                         2000. Performance in iteration
#                         50:
# Optimizing MAP estimate. Iterations: 57 /lized log-prob
#                         2000. Performance in iteration
#                         50:
# Optimizing MAP estimate. Iterations: 58 /lized log-prob
#                         2000. Performance in iteration
#                         50:
# Optimizing MAP estimate. Iterations: 59 /lized log-prob
#                         2000. Performance in iteration
#                         50:
# Optimizing MAP estimate. Iterations: 60 /lized log-prob
#                         2000. Performance in iteration
#                         60:
# Optimizing MAP estimate. Iterations: 61 /lized log-prob
#                         2000. Performance in iteration
#                         60:
# Optimizing MAP estimate. Iterations: 62 /lized log-prob
#                         2000. Performance in iteration
#                         60:
# Optimizing MAP estimate. Iterations: 63 /lized log-prob
#                         2000. Performance in iteration
#                         60:
# Optimizing MAP estimate. Iterations: 64 /lized log-prob
#                         2000. Performance in iteration
#                         60:
# Optimizing MAP estimate. Iterations: 65 /lized log-prob
#                         2000. Performance in iteration
#                         60:
# Optimizing MAP estimate. Iterations: 66 /lized log-prob
#                         2000. Performance in iteration
#                         60:
# Optimizing MAP estimate. Iterations: 67 /lized log-prob
#                         2000. Performance in iteration
#                         60:
# Optimizing MAP estimate. Iterations: 68 /lized log-prob
#                         2000. Performance in iteration
#                         60:
# Optimizing MAP estimate. Iterations: 69 /lized log-prob
#                         2000. Performance in iteration
#                         60:
# Optimizing MAP estimate. Iterations: 70 /lized log-prob
#                         2000. Performance in iteration
#                         70:
# Optimizing MAP estimate. Iterations: 71 /lized log-prob
#                         2000. Performance in iteration
#                         70:
# Optimizing MAP estimate. Iterations: 72 /lized log-prob
#                         2000. Performance in iteration
#                         70:
# Optimizing MAP estimate. Iterations: 73 /lized log-prob
#                         2000. Performance in iteration
#                         70:
# Optimizing MAP estimate. Iterations: 74 /lized log-prob
#                         2000. Performance in iteration
#                         70:
# Optimizing MAP estimate. Iterations: 75 /lized log-prob
#                         2000. Performance in iteration
#                         70:
# Optimizing MAP estimate. Iterations: 76 /lized log-prob
#                         2000. Performance in iteration
#                         70:
# Optimizing MAP estimate. Iterations: 77 /lized log-prob
#                         2000. Performance in iteration
#                         70:
# Optimizing MAP estimate. Iterations: 78 /lized log-prob
#                         2000. Performance in iteration
#                         70:
# Optimizing MAP estimate. Iterations: 79 /lized log-prob
#                         2000. Performance in iteration
#                         70:
# Optimizing MAP estimate. Iterations: 80 /lized log-prob
#                         2000. Performance in iteration
#                         80:
# Optimizing MAP estimate. Iterations: 81 /lized log-prob
#                         2000. Performance in iteration
#                         80:
# Optimizing MAP estimate. Iterations: 82 /lized log-prob
#                         2000. Performance in iteration
#                         80:
# Optimizing MAP estimate. Iterations: 83 /lized log-prob
#                         2000. Performance in iteration
#                         80:
# Optimizing MAP estimate. Iterations: 84 /lized log-prob
#                         2000. Performance in iteration
#                         80:
# Optimizing MAP estimate. Iterations: 85 /lized log-prob
#                         2000. Performance in iteration
#                         80:
# Optimizing MAP estimate. Iterations: 86 /lized log-prob
#                         2000. Performance in iteration
#                         80:
# Optimizing MAP estimate. Iterations: 87 /lized log-prob
#                         2000. Performance in iteration
#                         80:
# Optimizing MAP estimate. Iterations: 88 /lized log-prob
#                         2000. Performance in iteration
#                         80:
# Optimizing MAP estimate. Iterations: 89 /lized log-prob
#                         2000. Performance in iteration
#                         80:
# Optimizing MAP estimate. Iterations: 90 /lized log-prob
#                         2000. Performance in iteration
#                         90:
# Optimizing MAP estimate. Iterations: 91 /lized log-prob
#                         2000. Performance in iteration
#                         90:
# Optimizing MAP estimate. Iterations: 92 /lized log-prob
#                         2000. Performance in iteration
#                         90:
# Optimizing MAP estimate. Iterations: 93 /lized log-prob
#                         2000. Performance in iteration
#                         90:
# Optimizing MAP estimate. Iterations: 94 /lized log-prob
#                         2000. Performance in iteration
#                         90:
# Optimizing MAP estimate. Iterations: 95 /lized log-prob
#                         2000. Performance in iteration
#                         90:
# Optimizing MAP estimate. Iterations: 96 /lized log-prob
#                         2000. Performance in iteration
#                         90:
# Optimizing MAP estimate. Iterations: 97 /lized log-prob
#                         2000. Performance in iteration
#                         90:
# Optimizing MAP estimate. Iterations: 98 /lized log-prob
#                         2000. Performance in iteration
#                         90:
# Optimizing MAP estimate. Iterations: 99 /lized log-prob
#                         2000. Performance in iteration
#                         90:
# Optimizing MAP estimate. Iterations: 100 /ized log-prob
#                         2000. Performance in iteration
#                         100:
# Optimizing MAP estimate. Iterations: 101 /ized log-prob
#                         2000. Performance in iteration
#                         100:
# Optimizing MAP estimate. Iterations: 102 /ized log-prob
#                         2000. Performance in iteration
#                         100:
# Optimizing MAP estimate. Iterations: 103 /ized log-prob
#                         2000. Performance in iteration
#                         100:
# Optimizing MAP estimate. Iterations: 104 /ized log-prob
#                         2000. Performance in iteration
#                         100:
# Optimizing MAP estimate. Iterations: 105 /ized log-prob
#                         2000. Performance in iteration
#                         100:
# Optimizing MAP estimate. Iterations: 106 /ized log-prob
#                         2000. Performance in iteration
#                         100:
# Optimizing MAP estimate. Iterations: 107 /ized log-prob
#                         2000. Performance in iteration
#                         100:
# Optimizing MAP estimate. Iterations: 108 /ized log-prob
#                         2000. Performance in iteration
#                         100:
# Optimizing MAP estimate. Iterations: 109 /ized log-prob
#                         2000. Performance in iteration
#                         100:
# Optimizing MAP estimate. Iterations: 110 /ized log-prob
#                         2000. Performance in iteration
#                         110:
# Optimizing MAP estimate. Iterations: 111 /ized log-prob
#                         2000. Performance in iteration
#                         110:
# Optimizing MAP estimate. Iterations: 112 /ized log-prob
#                         2000. Performance in iteration
#                         110:
# Optimizing MAP estimate. Iterations: 113 /ized log-prob
#                         2000. Performance in iteration
#                         110:
# Optimizing MAP estimate. Iterations: 114 /ized log-prob
#                         2000. Performance in iteration
#                         110:
# Optimizing MAP estimate. Iterations: 115 /ized log-prob
#                         2000. Performance in iteration
#                         110:
# Optimizing MAP estimate. Iterations: 116 /ized log-prob
#                         2000. Performance in iteration
#                         110:
# Optimizing MAP estimate. Iterations: 117 /ized log-prob
#                         2000. Performance in iteration
#                         110:
# Optimizing MAP estimate. Iterations: 118 /ized log-prob
#                         2000. Performance in iteration
#                         110:
# Optimizing MAP estimate. Iterations: 119 /ized log-prob
#                         2000. Performance in iteration
#                         110:
# Optimizing MAP estimate. Iterations: 120 /ized log-prob
#                         2000. Performance in iteration
#                         120:
# Optimizing MAP estimate. Iterations: 121 /ized log-prob
#                         2000. Performance in iteration
#                         120:
# Optimizing MAP estimate. Iterations: 122 /ized log-prob
#                         2000. Performance in iteration
#                         120:
# Optimizing MAP estimate. Iterations: 123 /ized log-prob
#                         2000. Performance in iteration
#                         120:
# Optimizing MAP estimate. Iterations: 124 /ized log-prob
#                         2000. Performance in iteration
#                         120:
# Optimizing MAP estimate. Iterations: 125 /ized log-prob
#                         2000. Performance in iteration
#                         120:
# Optimizing MAP estimate. Iterations: 126 /ized log-prob
#                         2000. Performance in iteration
#                         120:
# Optimizing MAP estimate. Iterations: 127 /ized log-prob
#                         2000. Performance in iteration
#                         120:
# Optimizing MAP estimate. Iterations: 128 /ized log-prob
#                         2000. Performance in iteration
#                         120:
# Optimizing MAP estimate. Iterations: 129 /ized log-prob
#                         2000. Performance in iteration
#                         120:
# Optimizing MAP estimate. Iterations: 130 /ized log-prob
#                         2000. Performance in iteration
#                         130:
# Optimizing MAP estimate. Iterations: 131 /ized log-prob
#                         2000. Performance in iteration
#                         130:
# Optimizing MAP estimate. Iterations: 132 /ized log-prob
#                         2000. Performance in iteration
#                         130:
# Optimizing MAP estimate. Iterations: 133 /ized log-prob
#                         2000. Performance in iteration
#                         130:
# Optimizing MAP estimate. Iterations: 134 /ized log-prob
#                         2000. Performance in iteration
#                         130:
# Optimizing MAP estimate. Iterations: 135 /ized log-prob
#                         2000. Performance in iteration
#                         130:
# Optimizing MAP estimate. Iterations: 136 /ized log-prob
#                         2000. Performance in iteration
#                         130:
# Optimizing MAP estimate. Iterations: 137 /ized log-prob
#                         2000. Performance in iteration
#                         130:
# Optimizing MAP estimate. Iterations: 138 /ized log-prob
#                         2000. Performance in iteration
#                         130:
# Optimizing MAP estimate. Iterations: 139 /ized log-prob
#                         2000. Performance in iteration
#                         130:
# Optimizing MAP estimate. Iterations: 140 /ized log-prob
#                         2000. Performance in iteration
#                         140:
# Optimizing MAP estimate. Iterations: 141 /ized log-prob
#                         2000. Performance in iteration
#                         140:
# Optimizing MAP estimate. Iterations: 142 /ized log-prob
#                         2000. Performance in iteration
#                         140:
# Optimizing MAP estimate. Iterations: 143 /ized log-prob
#                         2000. Performance in iteration
#                         140:
# Optimizing MAP estimate. Iterations: 144 /ized log-prob
#                         2000. Performance in iteration
#                         140:
# Optimizing MAP estimate. Iterations: 145 /ized log-prob
#                         2000. Performance in iteration
#                         140:
# Optimizing MAP estimate. Iterations: 146 /ized log-prob
#                         2000. Performance in iteration
#                         140:
# Optimizing MAP estimate. Iterations: 147 /ized log-prob
#                         2000. Performance in iteration
#                         140:
# Optimizing MAP estimate. Iterations: 148 /ized log-prob
#                         2000. Performance in iteration
#                         140:
# Optimizing MAP estimate. Iterations: 149 /ized log-prob
#                         2000. Performance in iteration
#                         140:
# Optimizing MAP estimate. Iterations: 150 /ized log-prob
#                         2000. Performance in iteration
#                         150:
# Optimizing MAP estimate. Iterations: 151 /ized log-prob
#                         2000. Performance in iteration
#                         150:
# Optimizing MAP estimate. Iterations: 152 /ized log-prob
#                         2000. Performance in iteration
#                         150:
# Optimizing MAP estimate. Iterations: 153 /ized log-prob
#                         2000. Performance in iteration
#                         150:
# Optimizing MAP estimate. Iterations: 154 /ized log-prob
#                         2000. Performance in iteration
#                         150:
# Optimizing MAP estimate. Iterations: 155 /ized log-prob
#                         2000. Performance in iteration
#                         150:
# Optimizing MAP estimate. Iterations: 156 /ized log-prob
#                         2000. Performance in iteration
#                         150:
# Optimizing MAP estimate. Iterations: 157 /ized log-prob
#                         2000. Performance in iteration
#                         150:
# Optimizing MAP estimate. Iterations: 158 /ized log-prob
#                         2000. Performance in iteration
#                         150:
# Optimizing MAP estimate. Iterations: 159 /ized log-prob
#                         2000. Performance in iteration
#                         150:
# Optimizing MAP estimate. Iterations: 160 /ized log-prob
#                         2000. Performance in iteration
#                         160:
# Optimizing MAP estimate. Iterations: 161 /ized log-prob
#                         2000. Performance in iteration
#                         160:
# Optimizing MAP estimate. Iterations: 162 /ized log-prob
#                         2000. Performance in iteration
#                         160:
# Optimizing MAP estimate. Iterations: 163 /ized log-prob
#                         2000. Performance in iteration
#                         160:
# Optimizing MAP estimate. Iterations: 164 /ized log-prob
#                         2000. Performance in iteration
#                         160:
# Optimizing MAP estimate. Iterations: 165 /ized log-prob
#                         2000. Performance in iteration
#                         160:
# Optimizing MAP estimate. Iterations: 166 /ized log-prob
#                         2000. Performance in iteration
#                         160:
# Optimizing MAP estimate. Iterations: 167 /ized log-prob
#                         2000. Performance in iteration
#                         160:
# Optimizing MAP estimate. Iterations: 168 /ized log-prob
#                         2000. Performance in iteration
#                         160:
# Optimizing MAP estimate. Iterations: 169 /ized log-prob
#                         2000. Performance in iteration
#                         160:
# Optimizing MAP estimate. Iterations: 170 /ized log-prob
#                         2000. Performance in iteration
#                         170:
# Optimizing MAP estimate. Iterations: 171 /ized log-prob
#                         2000. Performance in iteration
#                         170:
# Optimizing MAP estimate. Iterations: 172 /ized log-prob
#                         2000. Performance in iteration
#                         170:
# Optimizing MAP estimate. Iterations: 173 /ized log-prob
#                         2000. Performance in iteration
#                         170:
# Optimizing MAP estimate. Iterations: 174 /ized log-prob
#                         2000. Performance in iteration
#                         170:
# Optimizing MAP estimate. Iterations: 175 /ized log-prob
#                         2000. Performance in iteration
#                         170:
# Optimizing MAP estimate. Iterations: 176 /ized log-prob
#                         2000. Performance in iteration
#                         170:
# Optimizing MAP estimate. Iterations: 177 /ized log-prob
#                         2000. Performance in iteration
#                         170:
# Optimizing MAP estimate. Iterations: 178 /ized log-prob
#                         2000. Performance in iteration
#                         170:
# Optimizing MAP estimate. Iterations: 179 /ized log-prob
#                         2000. Performance in iteration
#                         170:
# Optimizing MAP estimate. Iterations: 180 /ized log-prob
#                         2000. Performance in iteration
#                         180:
# Optimizing MAP estimate. Iterations: 181 /ized log-prob
#                         2000. Performance in iteration
#                         180:
# Optimizing MAP estimate. Iterations: 182 /ized log-prob
#                         2000. Performance in iteration
#                         180:
# Optimizing MAP estimate. Iterations: 183 /ized log-prob
#                         2000. Performance in iteration
#                         180:
# Optimizing MAP estimate. Iterations: 184 /ized log-prob
#                         2000. Performance in iteration
#                         180:
# Optimizing MAP estimate. Iterations: 185 /ized log-prob
#                         2000. Performance in iteration
#                         180:
# Optimizing MAP estimate. Iterations: 186 /ized log-prob
#                         2000. Performance in iteration
#                         180:
# Optimizing MAP estimate. Iterations: 187 /ized log-prob
#                         2000. Performance in iteration
#                         180:
# Optimizing MAP estimate. Iterations: 188 /ized log-prob
#                         2000. Performance in iteration
#                         180:
# Optimizing MAP estimate. Iterations: 189 /ized log-prob
#                         2000. Performance in iteration
#                         180:
# Optimizing MAP estimate. Iterations: 190 /ized log-prob
#                         2000. Performance in iteration
#                         190:
# Optimizing MAP estimate. Iterations: 191 /ized log-prob
#                         2000. Performance in iteration
#                         190:
# Optimizing MAP estimate. Iterations: 192 /ized log-prob
#                         2000. Performance in iteration
#                         190:
# Optimizing MAP estimate. Iterations: 193 /ized log-prob
#                         2000. Performance in iteration
#                         190:
# Optimizing MAP estimate. Iterations: 194 /ized log-prob
#                         2000. Performance in iteration
#                         190:
# Optimizing MAP estimate. Iterations: 195 /ized log-prob
#                         2000. Performance in iteration
#                         190:
# Optimizing MAP estimate. Iterations: 196 /ized log-prob
#                         2000. Performance in iteration
#                         190:
# Optimizing MAP estimate. Iterations: 197 /ized log-prob
#                         2000. Performance in iteration
#                         190:
# Optimizing MAP estimate. Iterations: 198 /ized log-prob
#                         2000. Performance in iteration
#                         190:
# Optimizing MAP estimate. Iterations: 199 /ized log-prob
#                         2000. Performance in iteration
#                         190:
# Optimizing MAP estimate. Iterations: 200 /ized log-prob
#                         2000. Performance in iteration
#                         200:
# Optimizing MAP estimate. Iterations: 201 /ized log-prob
#                         2000. Performance in iteration
#                         200:
# Optimizing MAP estimate. Iterations: 202 /ized log-prob
#                         2000. Performance in iteration
#                         200:
# Optimizing MAP estimate. Iterations: 203 /ized log-prob
#                         2000. Performance in iteration
#                         200:
# Optimizing MAP estimate. Iterations: 204 /ized log-prob
#                         2000. Performance in iteration
#                         200:
# Optimizing MAP estimate. Iterations: 205 /ized log-prob
#                         2000. Performance in iteration
#                         200:
# Optimizing MAP estimate. Iterations: 206 /ized log-prob
#                         2000. Performance in iteration
#                         200:
# Optimizing MAP estimate. Iterations: 207 /ized log-prob
#                         2000. Performance in iteration
#                         200:
# Optimizing MAP estimate. Iterations: 208 /ized log-prob
#                         2000. Performance in iteration
#                         200:
# Optimizing MAP estimate. Iterations: 209 /ized log-prob
#                         2000. Performance in iteration
#                         200:
# Optimizing MAP estimate. Iterations: 210 /ized log-prob
#                         2000. Performance in iteration
#                         210:
# Optimizing MAP estimate. Iterations: 211 /ized log-prob
#                         2000. Performance in iteration
#                         210:
# Optimizing MAP estimate. Iterations: 212 /ized log-prob
#                         2000. Performance in iteration
#                         210:
# Optimizing MAP estimate. Iterations: 213 /ized log-prob
#                         2000. Performance in iteration
#                         210:
# Optimizing MAP estimate. Iterations: 214 /ized log-prob
#                         2000. Performance in iteration
#                         210:
# Optimizing MAP estimate. Iterations: 215 /ized log-prob
#                         2000. Performance in iteration
#                         210:
# Optimizing MAP estimate. Iterations: 216 /ized log-prob
#                         2000. Performance in iteration
#                         210:
# Optimizing MAP estimate. Iterations: 217 /ized log-prob
#                         2000. Performance in iteration
#                         210:
# Optimizing MAP estimate. Iterations: 218 /ized log-prob
#                         2000. Performance in iteration
#                         210:
# Optimizing MAP estimate. Iterations: 219 /ized log-prob
#                         2000. Performance in iteration
#                         210:
# Optimizing MAP estimate. Iterations: 220 /ized log-prob
#                         2000. Performance in iteration
#                         220:
# Optimizing MAP estimate. Iterations: 221 /ized log-prob
#                         2000. Performance in iteration
#                         220:
# Optimizing MAP estimate. Iterations: 222 /ized log-prob
#                         2000. Performance in iteration
#                         220:
# Optimizing MAP estimate. Iterations: 223 /ized log-prob
#                         2000. Performance in iteration
#                         220:
# Optimizing MAP estimate. Iterations: 224 /ized log-prob
#                         2000. Performance in iteration
#                         220:
# Optimizing MAP estimate. Iterations: 225 /ized log-prob
#                         2000. Performance in iteration
#                         220:
# Optimizing MAP estimate. Iterations: 226 /ized log-prob
#                         2000. Performance in iteration
#                         220:
# Optimizing MAP estimate. Iterations: 227 /ized log-prob
#                         2000. Performance in iteration
#                         220:
# Optimizing MAP estimate. Iterations: 228 /ized log-prob
#                         2000. Performance in iteration
#                         220:
# Optimizing MAP estimate. Iterations: 229 /ized log-prob
#                         2000. Performance in iteration
#                         220:
# Optimizing MAP estimate. Iterations: 230 /ized log-prob
#                         2000. Performance in iteration
#                         230:
# Optimizing MAP estimate. Iterations: 231 /ized log-prob
#                         2000. Performance in iteration
#                         230:
# Optimizing MAP estimate. Iterations: 232 /ized log-prob
#                         2000. Performance in iteration
#                         230:
# Optimizing MAP estimate. Iterations: 233 /ized log-prob
#                         2000. Performance in iteration
#                         230:
# Optimizing MAP estimate. Iterations: 234 /ized log-prob
#                         2000. Performance in iteration
#                         230:
# Optimizing MAP estimate. Iterations: 235 /ized log-prob
#                         2000. Performance in iteration
#                         230:
# Optimizing MAP estimate. Iterations: 236 /ized log-prob
#                         2000. Performance in iteration
#                         230:
# Optimizing MAP estimate. Iterations: 237 /ized log-prob
#                         2000. Performance in iteration
#                         230:
# Optimizing MAP estimate. Iterations: 238 /ized log-prob
#                         2000. Performance in iteration
#                         230:
# Optimizing MAP estimate. Iterations: 239 /ized log-prob
#                         2000. Performance in iteration
#                         230:
# Optimizing MAP estimate. Iterations: 240 /ized log-prob
#                         2000. Performance in iteration
#                         240:
# Optimizing MAP estimate. Iterations: 241 /ized log-prob
#                         2000. Performance in iteration
#                         240:
# Optimizing MAP estimate. Iterations: 242 /ized log-prob
#                         2000. Performance in iteration
#                         240:
# Optimizing MAP estimate. Iterations: 243 /ized log-prob
#                         2000. Performance in iteration
#                         240:
# Optimizing MAP estimate. Iterations: 244 /ized log-prob
#                         2000. Performance in iteration
#                         240:
# Optimizing MAP estimate. Iterations: 245 /ized log-prob
#                         2000. Performance in iteration
#                         240:
# Optimizing MAP estimate. Iterations: 246 /ized log-prob
#                         2000. Performance in iteration
#                         240:
# Optimizing MAP estimate. Iterations: 247 /ized log-prob
#                         2000. Performance in iteration
#                         240:
# Optimizing MAP estimate. Iterations: 248 /ized log-prob
#                         2000. Performance in iteration
#                         240:
# Optimizing MAP estimate. Iterations: 249 /ized log-prob
#                         2000. Performance in iteration
#                         240:
# Optimizing MAP estimate. Iterations: 250 /ized log-prob
#                         2000. Performance in iteration
#                         250:
# Optimizing MAP estimate. Iterations: 251 /ized log-prob
#                         2000. Performance in iteration
#                         250:
# Optimizing MAP estimate. Iterations: 252 /ized log-prob
#                         2000. Performance in iteration
#                         250:
# Optimizing MAP estimate. Iterations: 253 /ized log-prob
#                         2000. Performance in iteration
#                         250:
# Optimizing MAP estimate. Iterations: 254 /ized log-prob
#                         2000. Performance in iteration
#                         250:
# Optimizing MAP estimate. Iterations: 255 /ized log-prob
#                         2000. Performance in iteration
#                         250:
# Optimizing MAP estimate. Iterations: 256 /ized log-prob
#                         2000. Performance in iteration
#                         250:
# Optimizing MAP estimate. Iterations: 257 /ized log-prob
#                         2000. Performance in iteration
#                         250:
# Optimizing MAP estimate. Iterations: 258 /ized log-prob
#                         2000. Performance in iteration
#                         250:
# Optimizing MAP estimate. Iterations: 259 /ized log-prob
#                         2000. Performance in iteration
#                         250:
# Optimizing MAP estimate. Iterations: 260 /ized log-prob
#                         2000. Performance in iteration
#                         260:
# Optimizing MAP estimate. Iterations: 261 /ized log-prob
#                         2000. Performance in iteration
#                         260:
# Optimizing MAP estimate. Iterations: 262 /ized log-prob
#                         2000. Performance in iteration
#                         260:
# Optimizing MAP estimate. Iterations: 263 /ized log-prob
#                         2000. Performance in iteration
#                         260:
# Optimizing MAP estimate. Iterations: 264 /ized log-prob
#                         2000. Performance in iteration
#                         260:
# Optimizing MAP estimate. Iterations: 265 /ized log-prob
#                         2000. Performance in iteration
#                         260:
# Optimizing MAP estimate. Iterations: 266 /ized log-prob
#                         2000. Performance in iteration
#                         260:
# Optimizing MAP estimate. Iterations: 267 /ized log-prob
#                         2000. Performance in iteration
#                         260:
# Optimizing MAP estimate. Iterations: 268 /ized log-prob
#                         2000. Performance in iteration
#                         260:
# Optimizing MAP estimate. Iterations: 269 /ized log-prob
#                         2000. Performance in iteration
#                         260:
# Optimizing MAP estimate. Iterations: 270 /ized log-prob
#                         2000. Performance in iteration
#                         270:
# Optimizing MAP estimate. Iterations: 271 /ized log-prob
#                         2000. Performance in iteration
#                         270:
# Optimizing MAP estimate. Iterations: 272 /ized log-prob
#                         2000. Performance in iteration
#                         270:
# Optimizing MAP estimate. Iterations: 273 /ized log-prob
#                         2000. Performance in iteration
#                         270:
# Optimizing MAP estimate. Iterations: 274 /ized log-prob
#                         2000. Performance in iteration
#                         270:
# Optimizing MAP estimate. Iterations: 275 /ized log-prob
#                         2000. Performance in iteration
#                         270:
# Optimizing MAP estimate. Iterations: 276 /ized log-prob
#                         2000. Performance in iteration
#                         270:
# Optimizing MAP estimate. Iterations: 277 /ized log-prob
#                         2000. Performance in iteration
#                         270:
# Optimizing MAP estimate. Iterations: 278 /ized log-prob
#                         2000. Performance in iteration
#                         270:
# Optimizing MAP estimate. Iterations: 279 /ized log-prob
#                         2000. Performance in iteration
#                         270:
# Optimizing MAP estimate. Iterations: 280 /ized log-prob
#                         2000. Performance in iteration
#                         280:
# Optimizing MAP estimate. Iterations: 281 /ized log-prob
#                         2000. Performance in iteration
#                         280:
# Optimizing MAP estimate. Iterations: 282 /ized log-prob
#                         2000. Performance in iteration
#                         280:
# Optimizing MAP estimate. Iterations: 283 /ized log-prob
#                         2000. Performance in iteration
#                         280:
# Optimizing MAP estimate. Iterations: 284 /ized log-prob
#                         2000. Performance in iteration
#                         280:
# Optimizing MAP estimate. Iterations: 285 /ized log-prob
#                         2000. Performance in iteration
#                         280:
# Optimizing MAP estimate. Iterations: 286 /ized log-prob
#                         2000. Performance in iteration
#                         280:
# Optimizing MAP estimate. Iterations: 287 /ized log-prob
#                         2000. Performance in iteration
#                         280:
# Optimizing MAP estimate. Iterations: 288 /ized log-prob
#                         2000. Performance in iteration
#                         280:
# Optimizing MAP estimate. Iterations: 289 /ized log-prob
#                         2000. Performance in iteration
#                         280:
# Optimizing MAP estimate. Iterations: 290 /ized log-prob
#                         2000. Performance in iteration
#                         290:
# Optimizing MAP estimate. Iterations: 291 /ized log-prob
#                         2000. Performance in iteration
#                         290:
# Optimizing MAP estimate. Iterations: 292 /ized log-prob
#                         2000. Performance in iteration
#                         290:
# Optimizing MAP estimate. Iterations: 293 /ized log-prob
#                         2000. Performance in iteration
#                         290:
# Optimizing MAP estimate. Iterations: 294 /ized log-prob
#                         2000. Performance in iteration
#                         290:
# Optimizing MAP estimate. Iterations: 295 /ized log-prob
#                         2000. Performance in iteration
#                         290:
# Optimizing MAP estimate. Iterations: 296 /ized log-prob
#                         2000. Performance in iteration
#                         290:
# Optimizing MAP estimate. Iterations: 297 /ized log-prob
#                         2000. Performance in iteration
#                         290:
# Optimizing MAP estimate. Iterations: 298 /ized log-prob
#                         2000. Performance in iteration
#                         290:
# Optimizing MAP estimate. Iterations: 299 /ized log-prob
#                         2000. Performance in iteration
#                         290:
# Optimizing MAP estimate. Iterations: 300 /ized log-prob
#                         2000. Performance in iteration
#                         300:
# Optimizing MAP estimate. Iterations: 301 /ized log-prob
#                         2000. Performance in iteration
#                         300:
# Optimizing MAP estimate. Iterations: 302 /ized log-prob
#                         2000. Performance in iteration
#                         300:
# Optimizing MAP estimate. Iterations: 303 /ized log-prob
#                         2000. Performance in iteration
#                         300:
# Optimizing MAP estimate. Iterations: 304 /ized log-prob
#                         2000. Performance in iteration
#                         300:
# Optimizing MAP estimate. Iterations: 305 /ized log-prob
#                         2000. Performance in iteration
#                         300:
# Optimizing MAP estimate. Iterations: 306 /ized log-prob
#                         2000. Performance in iteration
#                         300:
# Optimizing MAP estimate. Iterations: 307 /ized log-prob
#                         2000. Performance in iteration
#                         300:
# Optimizing MAP estimate. Iterations: 308 /ized log-prob
#                         2000. Performance in iteration
#                         300:
# Optimizing MAP estimate. Iterations: 309 /ized log-prob
#                         2000. Performance in iteration
#                         300:
# Optimizing MAP estimate. Iterations: 310 /ized log-prob
#                         2000. Performance in iteration
#                         310:
# Optimizing MAP estimate. Iterations: 311 /ized log-prob
#                         2000. Performance in iteration
#                         310:
# Optimizing MAP estimate. Iterations: 312 /ized log-prob
#                         2000. Performance in iteration
#                         310:
# Optimizing MAP estimate. Iterations: 313 /ized log-prob
#                         2000. Performance in iteration
#                         310:
# Optimizing MAP estimate. Iterations: 314 /ized log-prob
#                         2000. Performance in iteration
#                         310:
# Optimizing MAP estimate. Iterations: 315 /ized log-prob
#                         2000. Performance in iteration
#                         310:
# Optimizing MAP estimate. Iterations: 316 /ized log-prob
#                         2000. Performance in iteration
#                         310:
# Optimizing MAP estimate. Iterations: 317 /ized log-prob
#                         2000. Performance in iteration
#                         310:
# Optimizing MAP estimate. Iterations: 318 /ized log-prob
#                         2000. Performance in iteration
#                         310:
# Optimizing MAP estimate. Iterations: 319 /ized log-prob
#                         2000. Performance in iteration
#                         310:
# Optimizing MAP estimate. Iterations: 320 /ized log-prob
#                         2000. Performance in iteration
#                         320:
# Optimizing MAP estimate. Iterations: 321 /ized log-prob
#                         2000. Performance in iteration
#                         320:
# Optimizing MAP estimate. Iterations: 322 /ized log-prob
#                         2000. Performance in iteration
#                         320:
# Optimizing MAP estimate. Iterations: 323 /ized log-prob
#                         2000. Performance in iteration
#                         320:
# Optimizing MAP estimate. Iterations: 324 /ized log-prob
#                         2000. Performance in iteration
#                         320:
# Optimizing MAP estimate. Iterations: 325 /ized log-prob
#                         2000. Performance in iteration
#                         320:
# Optimizing MAP estimate. Iterations: 326 /ized log-prob
#                         2000. Performance in iteration
#                         320:
# Optimizing MAP estimate. Iterations: 327 /ized log-prob
#                         2000. Performance in iteration
#                         320:
# Optimizing MAP estimate. Iterations: 328 /ized log-prob
#                         2000. Performance in iteration
#                         320:
# Optimizing MAP estimate. Iterations: 329 /ized log-prob
#                         2000. Performance in iteration
#                         320:
# Optimizing MAP estimate. Iterations: 330 /ized log-prob
#                         2000. Performance in iteration
#                         330:
# Optimizing MAP estimate. Iterations: 331 /ized log-prob
#                         2000. Performance in iteration
#                         330:
# Optimizing MAP estimate. Iterations: 332 /ized log-prob
#                         2000. Performance in iteration
#                         330:
# Optimizing MAP estimate. Iterations: 333 /ized log-prob
#                         2000. Performance in iteration
#                         330:
# Optimizing MAP estimate. Iterations: 334 /ized log-prob
#                         2000. Performance in iteration
#                         330:
# Optimizing MAP estimate. Iterations: 335 /ized log-prob
#                         2000. Performance in iteration
#                         330:
# Optimizing MAP estimate. Iterations: 336 /ized log-prob
#                         2000. Performance in iteration
#                         330:
# Optimizing MAP estimate. Iterations: 337 /ized log-prob
#                         2000. Performance in iteration
#                         330:
# Optimizing MAP estimate. Iterations: 338 /ized log-prob
#                         2000. Performance in iteration
#                         330:
# Optimizing MAP estimate. Iterations: 339 /ized log-prob
#                         2000. Performance in iteration
#                         330:
# Optimizing MAP estimate. Iterations: 340 /ized log-prob
#                         2000. Performance in iteration
#                         340:
# Optimizing MAP estimate. Iterations: 341 /ized log-prob
# ...
# Optimizing MAP estimate. Iterations: 1888 /zed log-prob
#                         2000. Performance in iteration
#                         1880:
# Optimizing MAP estimate. Iterations: 1889 /zed log-prob
#                         2000. Performance in iteration
#                         1880:
# Optimizing MAP estimate. Iterations: 1890 /zed log-prob
#                         2000. Performance in iteration
#                         1890:
# Optimizing MAP estimate. Iterations: 1891 /zed log-prob
#                         2000. Performance in iteration
#                         1890:
# Optimizing MAP estimate. Iterations: 1892 /zed log-prob
#                         2000. Performance in iteration
#                         1890:
# Optimizing MAP estimate. Iterations: 1893 /zed log-prob
#                         2000. Performance in iteration
#                         1890:
# Optimizing MAP estimate. Iterations: 1894 /zed log-prob
#                         2000. Performance in iteration
#                         1890:
# Optimizing MAP estimate. Iterations: 1895 /zed log-prob
#                         2000. Performance in iteration
#                         1890:
# Optimizing MAP estimate. Iterations: 1896 /zed log-prob
#                         2000. Performance in iteration
#                         1890:
# Optimizing MAP estimate. Iterations: 1897 /zed log-prob
#                         2000. Performance in iteration
#                         1890:
# Optimizing MAP estimate. Iterations: 1898 /zed log-prob
#                         2000. Performance in iteration
#                         1890:
# Optimizing MAP estimate. Iterations: 1899 /zed log-prob
#                         2000. Performance in iteration
#                         1890:
# Optimizing MAP estimate. Iterations: 1900 /zed log-prob
#                         2000. Performance in iteration
#                         1900:
# Optimizing MAP estimate. Iterations: 1901 /zed log-prob
#                         2000. Performance in iteration
#                         1900:
# Optimizing MAP estimate. Iterations: 1902 /zed log-prob
#                         2000. Performance in iteration
#                         1900:
# Optimizing MAP estimate. Iterations: 1903 /zed log-prob
#                         2000. Performance in iteration
#                         1900:
# Optimizing MAP estimate. Iterations: 1904 /zed log-prob
#                         2000. Performance in iteration
#                         1900:
# Optimizing MAP estimate. Iterations: 1905 /zed log-prob
#                         2000. Performance in iteration
#                         1900:
# Optimizing MAP estimate. Iterations: 1906 /zed log-prob
#                         2000. Performance in iteration
#                         1900:
# Optimizing MAP estimate. Iterations: 1907 /zed log-prob
#                         2000. Performance in iteration
#                         1900:
# Optimizing MAP estimate. Iterations: 1908 /zed log-prob
#                         2000. Performance in iteration
#                         1900:
# Optimizing MAP estimate. Iterations: 1909 /zed log-prob
#                         2000. Performance in iteration
#                         1900:
# Optimizing MAP estimate. Iterations: 1910 /zed log-prob
#                         2000. Performance in iteration
#                         1910:
# Optimizing MAP estimate. Iterations: 1911 /zed log-prob
#                         2000. Performance in iteration
#                         1910:
# Optimizing MAP estimate. Iterations: 1912 /zed log-prob
#                         2000. Performance in iteration
#                         1910:
# Optimizing MAP estimate. Iterations: 1913 /zed log-prob
#                         2000. Performance in iteration
#                         1910:
# Optimizing MAP estimate. Iterations: 1914 /zed log-prob
#                         2000. Performance in iteration
#                         1910:
# Optimizing MAP estimate. Iterations: 1915 /zed log-prob
#                         2000. Performance in iteration
#                         1910:
# Optimizing MAP estimate. Iterations: 1916 /zed log-prob
#                         2000. Performance in iteration
#                         1910:
# Optimizing MAP estimate. Iterations: 1917 /zed log-prob
#                         2000. Performance in iteration
#                         1910:
# Optimizing MAP estimate. Iterations: 1918 /zed log-prob
#                         2000. Performance in iteration
#                         1910:
# Optimizing MAP estimate. Iterations: 1919 /zed log-prob
#                         2000. Performance in iteration
#                         1910:
# Optimizing MAP estimate. Iterations: 1920 /zed log-prob
#                         2000. Performance in iteration
#                         1920:
# Optimizing MAP estimate. Iterations: 1921 /zed log-prob
#                         2000. Performance in iteration
#                         1920:
# Optimizing MAP estimate. Iterations: 1922 /zed log-prob
#                         2000. Performance in iteration
#                         1920:
# Optimizing MAP estimate. Iterations: 1923 /zed log-prob
#                         2000. Performance in iteration
#                         1920:
# Optimizing MAP estimate. Iterations: 1924 /zed log-prob
#                         2000. Performance in iteration
#                         1920:
# Optimizing MAP estimate. Iterations: 1925 /zed log-prob
#                         2000. Performance in iteration
#                         1920:
# Optimizing MAP estimate. Iterations: 1926 /zed log-prob
#                         2000. Performance in iteration
#                         1920:
# Optimizing MAP estimate. Iterations: 1927 /zed log-prob
#                         2000. Performance in iteration
#                         1920:
# Optimizing MAP estimate. Iterations: 1928 /zed log-prob
#                         2000. Performance in iteration
#                         1920:
# Optimizing MAP estimate. Iterations: 1929 /zed log-prob
#                         2000. Performance in iteration
#                         1920:
# Optimizing MAP estimate. Iterations: 1930 /zed log-prob
#                         2000. Performance in iteration
#                         1930:
# Optimizing MAP estimate. Iterations: 1931 /zed log-prob
#                         2000. Performance in iteration
#                         1930:
# Optimizing MAP estimate. Iterations: 1932 /zed log-prob
#                         2000. Performance in iteration
#                         1930:
# Optimizing MAP estimate. Iterations: 1933 /zed log-prob
#                         2000. Performance in iteration
#                         1930:
# Optimizing MAP estimate. Iterations: 1934 /zed log-prob
#                         2000. Performance in iteration
#                         1930:
# Optimizing MAP estimate. Iterations: 1935 /zed log-prob
#                         2000. Performance in iteration
#                         1930:
# Optimizing MAP estimate. Iterations: 1936 /zed log-prob
#                         2000. Performance in iteration
#                         1930:
# Optimizing MAP estimate. Iterations: 1937 /zed log-prob
#                         2000. Performance in iteration
#                         1930:
# Optimizing MAP estimate. Iterations: 1938 /zed log-prob
#                         2000. Performance in iteration
#                         1930:
# Optimizing MAP estimate. Iterations: 1939 /zed log-prob
#                         2000. Performance in iteration
#                         1930:
# Optimizing MAP estimate. Iterations: 1940 /zed log-prob
#                         2000. Performance in iteration
#                         1940:
# Optimizing MAP estimate. Iterations: 1941 /zed log-prob
#                         2000. Performance in iteration
#                         1940:
# Optimizing MAP estimate. Iterations: 1942 /zed log-prob
#                         2000. Performance in iteration
#                         1940:
# Optimizing MAP estimate. Iterations: 1943 /zed log-prob
#                         2000. Performance in iteration
#                         1940:
# Optimizing MAP estimate. Iterations: 1944 /zed log-prob
#                         2000. Performance in iteration
#                         1940:
# Optimizing MAP estimate. Iterations: 1945 /zed log-prob
#                         2000. Performance in iteration
#                         1940:
# Optimizing MAP estimate. Iterations: 1946 /zed log-prob
#                         2000. Performance in iteration
#                         1940:
# Optimizing MAP estimate. Iterations: 1947 /zed log-prob
#                         2000. Performance in iteration
#                         1940:
# Optimizing MAP estimate. Iterations: 1948 /zed log-prob
#                         2000. Performance in iteration
#                         1940:
# Optimizing MAP estimate. Iterations: 1949 /zed log-prob
#                         2000. Performance in iteration
#                         1940:
# Optimizing MAP estimate. Iterations: 1950 /zed log-prob
#                         2000. Performance in iteration
#                         1950:
# Optimizing MAP estimate. Iterations: 1951 /zed log-prob
#                         2000. Performance in iteration
#                         1950:
# Optimizing MAP estimate. Iterations: 1952 /zed log-prob
#                         2000. Performance in iteration
#                         1950:
# Optimizing MAP estimate. Iterations: 1953 /zed log-prob
#                         2000. Performance in iteration
#                         1950:
# Optimizing MAP estimate. Iterations: 1954 /zed log-prob
#                         2000. Performance in iteration
#                         1950:
# Optimizing MAP estimate. Iterations: 1955 /zed log-prob
#                         2000. Performance in iteration
#                         1950:
# Optimizing MAP estimate. Iterations: 1956 /zed log-prob
#                         2000. Performance in iteration
#                         1950:
# Optimizing MAP estimate. Iterations: 1957 /zed log-prob
#                         2000. Performance in iteration
#                         1950:
# Optimizing MAP estimate. Iterations: 1958 /zed log-prob
#                         2000. Performance in iteration
#                         1950:
# Optimizing MAP estimate. Iterations: 1959 /zed log-prob
#                         2000. Performance in iteration
#                         1950:
# Optimizing MAP estimate. Iterations: 1960 /zed log-prob
#                         2000. Performance in iteration
#                         1960:
# Optimizing MAP estimate. Iterations: 1961 /zed log-prob
#                         2000. Performance in iteration
#                         1960:
# Optimizing MAP estimate. Iterations: 1962 /zed log-prob
#                         2000. Performance in iteration
#                         1960:
# Optimizing MAP estimate. Iterations: 1963 /zed log-prob
#                         2000. Performance in iteration
#                         1960:
# Optimizing MAP estimate. Iterations: 1964 /zed log-prob
#                         2000. Performance in iteration
#                         1960:
# Optimizing MAP estimate. Iterations: 1965 /zed log-prob
#                         2000. Performance in iteration
#                         1960:
# Optimizing MAP estimate. Iterations: 1966 /zed log-prob
#                         2000. Performance in iteration
#                         1960:
# Optimizing MAP estimate. Iterations: 1967 /zed log-prob
#                         2000. Performance in iteration
#                         1960:
# Optimizing MAP estimate. Iterations: 1968 /zed log-prob
#                         2000. Performance in iteration
#                         1960:
# Optimizing MAP estimate. Iterations: 1969 /zed log-prob
#                         2000. Performance in iteration
#                         1960:
# Optimizing MAP estimate. Iterations: 1970 /zed log-prob
#                         2000. Performance in iteration
#                         1970:
# Optimizing MAP estimate. Iterations: 1971 /zed log-prob
#                         2000. Performance in iteration
#                         1970:
# Optimizing MAP estimate. Iterations: 1972 /zed log-prob
#                         2000. Performance in iteration
#                         1970:
# Optimizing MAP estimate. Iterations: 1973 /zed log-prob
#                         2000. Performance in iteration
#                         1970:
# Optimizing MAP estimate. Iterations: 1974 /zed log-prob
#                         2000. Performance in iteration
#                         1970:
# Optimizing MAP estimate. Iterations: 1975 /zed log-prob
#                         2000. Performance in iteration
#                         1970:
# Optimizing MAP estimate. Iterations: 1976 /zed log-prob
#                         2000. Performance in iteration
#                         1970:
# Optimizing MAP estimate. Iterations: 1977 /zed log-prob
#                         2000. Performance in iteration
#                         1970:
# Optimizing MAP estimate. Iterations: 1978 /zed log-prob
#                         2000. Performance in iteration
#                         1970:
# Optimizing MAP estimate. Iterations: 1979 /zed log-prob
#                         2000. Performance in iteration
#                         1970:
# Optimizing MAP estimate. Iterations: 1980 /zed log-prob
#                         2000. Performance in iteration
#                         1980:
# Optimizing MAP estimate. Iterations: 1981 /zed log-prob
#                         2000. Performance in iteration
#                         1980:
# Optimizing MAP estimate. Iterations: 1982 /zed log-prob
#                         2000. Performance in iteration
#                         1980:
# Optimizing MAP estimate. Iterations: 1983 /zed log-prob
#                         2000. Performance in iteration
#                         1980:
# Optimizing MAP estimate. Iterations: 1984 /zed log-prob
#                         2000. Performance in iteration
#                         1980:
# Optimizing MAP estimate. Iterations: 1985 /zed log-prob
#                         2000. Performance in iteration
#                         1980:
# Optimizing MAP estimate. Iterations: 1986 /zed log-prob
#                         2000. Performance in iteration
#                         1980:
# Optimizing MAP estimate. Iterations: 1987 /zed log-prob
#                         2000. Performance in iteration
#                         1980:
# Optimizing MAP estimate. Iterations: 1988 /zed log-prob
#                         2000. Performance in iteration
#                         1980:
# Optimizing MAP estimate. Iterations: 1989 /zed log-prob
#                         2000. Performance in iteration
#                         1980:
# Optimizing MAP estimate. Iterations: 1990 /zed log-prob
#                         2000. Performance in iteration
#                         1990:
# Optimizing MAP estimate. Iterations: 1991 /zed log-prob
#                         2000. Performance in iteration
#                         1990:
# Optimizing MAP estimate. Iterations: 1992 /zed log-prob
#                         2000. Performance in iteration
#                         1990:
# Optimizing MAP estimate. Iterations: 1993 /zed log-prob
#                         2000. Performance in iteration
#                         1990:
# Optimizing MAP estimate. Iterations: 1994 /zed log-prob
#                         2000. Performance in iteration
#                         1990:
# Optimizing MAP estimate. Iterations: 1995 /zed log-prob
#                         2000. Performance in iteration
#                         1990:
# Optimizing MAP estimate. Iterations: 1996 /zed log-prob
#                         2000. Performance in iteration
#                         1990:
# Optimizing MAP estimate. Iterations: 1997 /zed log-prob
#                         2000. Performance in iteration
#                         1990:
# Optimizing MAP estimate. Iterations: 1998 /zed log-prob
#                         2000. Performance in iteration
#                         1990:
# Optimizing MAP estimate. Iterations: 1999 /zed log-prob
#                         2000. Performance in iteration
#                         1990:
# Optimizing MAP estimate. Iterations: 2000 /zed log-prob
#                         2000. Performance in iteration
#                         2000:
#                         -34.39 (= unnormalized log-prob

# %%
print(MAP)
# Out:
# tensor([ 2.8082e+02,  5.0793e+00,  3.9233e+00,  4.1607e+01,  9.1361e+00,
#          1.2681e+02,  6.0581e-03,  5.2989e-03,  1.2366e+02,  7.4288e-01,
#          5.9172e+00,  4.5291e+01,  7.3667e+00,  1.0132e+02,  4.9749e-02,
#          3.2966e-02,  3.3083e+02,  9.2330e+00,  3.4651e+00,  4.2799e+01,
#          1.2948e+00,  1.0375e+02,  2.6046e-02,  2.7279e-02, -7.8942e+00,
#         -1.5622e+01, -1.5408e+01, -8.5999e+00, -9.0348e+00, -1.7256e+01,
#         -8.9691e+00])

# %%
labels_ = ['AB-Na    $\\;\\;$',
 'AB-CaT    $\\;\\;$',
 'AB-CaS    $\\;\\;$',
 'AB-A    $\\;\\;$',
 'AB-KCa    $\\;\\;$',
 'AB-Kd    $\\;\\;$',
 'AB-H    $\\;\\;$',
 'AB-leak    $\\;\\;$',
 'LP-Na    $\\;\\;$',
 'LP-CaT    $\\;\\;$',
 'LP-CaS    $\\;\\;$',
 'LP-A    $\\;\\;$',
 'LP-KCa    $\\;\\;$',
 'LP-Kd    $\\;\\;$',
 'LP-H    $\\;\\;$',
 'LP-leak    $\\;\\;$',
 'PY-Na    $\\;\\;$',
 'PY-CaT    $\\;\\;$',
 'PY-CaS    $\\;\\;$',
 'PY-A    $\\;\\;$',
 'PY-KCa    $\\;\\;$',
 'PY-Kd    $\\;\\;$',
 'PY-H    $\\;\\;$',
 'PY-leak    $\\;\\;$',
 '$\\mathdefault{AB-LP}$    $\\;\\;$',
 '$\\mathdefault{PD-LP}$    $\\;\\;$',
 '$\\mathdefault{AB-PY}$    $\\;\\;$',
 '$\\mathdefault{PD-PY}$    $\\;\\;$',
 '$\\mathdefault{LP-PD}$    $\\;\\;$',
 '$\\mathdefault{LP-PY}$    $\\;\\;$',
 '$\\mathdefault{PY-LP}$    $\\;\\;$',
 '$\\mathrm{Q}_{\\mathrm{10}} \\mathrm{Na}$    $\\;\\;$',
 '$\\mathrm{Q}_{\\mathrm{10}} \\mathrm{CaT}$    $\\;\\;$',
 '$\\mathrm{Q}_{\\mathrm{10}} \\mathrm{CaS}$    $\\;\\;$',
 '$\\mathrm{Q}_{\\mathrm{10}} \\mathrm{CaA}$    $\\;\\;$',
 '$\\mathrm{Q}_{\\mathrm{10}} \\mathrm{KCa}$    $\\;\\;$',
 '$\\mathrm{Q}_{\\mathrm{10}} \\mathrm{Kd}$    $\\;\\;$',
 '$\\mathrm{Q}_{\\mathrm{10}} \\mathrm{H}$    $\\;\\;$',
 '$\\mathrm{Q}_{\\mathrm{10}} \\mathrm{leak}$    $\\;\\;$',
 '$\\mathrm{Q}_{\\mathrm{10}} \\mathrm{glut}$    $\\;\\;$',
 '$\\mathrm{Q}_{\\mathrm{10}} \\mathrm{chol}$    $\\;\\;$']

all_labels = [['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{500}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{7}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{8}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{60}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{15}\\;\\;\\;$   '],
 ['$\\mathdefault{25}\\;\\;\\;$      ', '$\\mathdefault{150}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{0.0}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{0.01}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{200}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{2}\\;\\;\\;$   '],
 ['$\\mathdefault{2}\\;\\;\\;$      ', '$\\mathdefault{12}\\;\\;\\;$   '],
 ['$\\mathdefault{10}\\;\\;\\;$      ', '$\\mathdefault{60}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{10}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{125}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{0.1}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{0.0}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{600}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{12}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{4}\\;\\;\\;$   '],
 ['$\\mathdefault{30}\\;\\;\\;$      ', '$\\mathdefault{60}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{5}\\;\\;\\;$   '],
 ['$\\mathdefault{50}\\;\\;\\;$      ', '$\\mathdefault{150}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{0.1}\\;\\;\\;$   '],
 ['$\\mathdefault{0.0}\\;\\;\\;$      ', '$\\mathdefault{0.0}\\;\\;\\;$   '],
 ['$\\mathdefault{0.01}\\;\\;\\;\\;\\;\\;\\;$         ',
  '$\\mathdefault{10000}\\;\\;\\;\\;\\;\\;$    '],
 ['$\\;\\;\\mathdefault{0.01}\\;\\;\\;\\;\\;$       ',
  '$\\mathdefault{1000}\\;\\;\\;\\;\\;$  '],
 ['$\\;\\;\\mathdefault{0.01}\\;\\;\\;\\;\\;$       ',
  '$\\mathdefault{1000}\\;\\;\\;\\;\\;$  '],
 ['$\\;\\;\\mathdefault{0.01}\\;\\;\\;\\;\\;$       ',
  '$\\mathdefault{1000}\\;\\;\\;\\;\\;$  '],
 ['$\\;\\;\\mathdefault{0.01}\\;\\;\\;\\;\\;$       ',
  '$\\mathdefault{1000}\\;\\;\\;\\;\\;$  '],
 ['$\\;\\;\\mathdefault{0.01}\\;\\;\\;\\;\\;$       ',
  '$\\mathdefault{1000}\\;\\;\\;\\;\\;$  '],
 ['$\\;\\;\\mathdefault{0.01}\\;\\;\\;\\;\\;$       ',
  '$\\mathdefault{1000}\\;\\;\\;\\;\\;$  ']]

# %%
lims = np.asarray([[ 0.0000000e+00,  5.0000000e+02],
       [ 0.0000000e+00,  7.5000000e+00],
       [ 0.0000000e+00,  8.0000000e+00],
       [ 0.0000000e+00,  6.0000000e+01],
       [ 0.0000000e+00,  1.5000000e+01],
       [ 2.5000000e+01,  1.5000000e+02],
       [ 0.0000000e+00,  2.0000000e-02],
       [ 0.0000000e+00,  9.9999998e-03],
       [ 0.0000000e+00,  2.0000000e+02],
       [ 0.0000000e+00,  2.5000000e+00],
       [ 2.0000000e+00,  1.2000000e+01],
       [ 1.0000000e+01,  6.0000000e+01],
       [ 0.0000000e+00,  1.0000000e+01],
       [ 0.0000000e+00,  1.2500000e+02],
       [ 0.0000000e+00,  5.9999999e-02],
       [ 9.9999998e-03,  3.9999999e-02],
       [ 0.0000000e+00,  6.0000000e+02],
       [ 0.0000000e+00,  1.2500000e+01],
       [ 0.0000000e+00,  4.0000000e+00],
       [ 3.0000000e+01,  6.0000000e+01],
       [ 0.0000000e+00,  5.0000000e+00],
       [ 5.0000000e+01,  1.5000000e+02],
       [ 0.0000000e+00,  5.9999999e-02],
       [ 0.0000000e+00,  3.9999999e-02],
       [-1.8420681e+01, -4.6051702e+00],
       [-1.8420681e+01, -6.9077554e+00],
       [-1.8420681e+01, -6.9077554e+00],
       [-1.8420681e+01, -6.9077554e+00],
       [-1.8420681e+01, -6.9077554e+00],
       [-1.8420681e+01, -6.9077554e+00],
       [-1.8420681e+01, -6.9077554e+00]], dtype=np.float32)

# %%
import matplotlib as mpl
with mpl.rc_context(fname='../../.matplotlibrc'):
    mpl.rc('font',family='DejaVu Sans')
    fig, axes = pairplot(
            samples=[samples[:100]],
            labelpad=100,
            tick_labelpad=1,
            limits=lims,
            ticks=lims,
            tick_labels=all_labels,
            fig_size=(10.45, 10.45),
            labels=labels_,
            scatter_offdiag={'rasterized':True, 'alpha':1.0},
            diag=['kde'],
            upper=['kde'],
            hist_offdiag={'bins':50},
            plot_offdiag={'linewidth': 1.6},
            points=[MEAN, MAP], points_colors=["black", "red"], points_offdiag={"markersize":2}
        )
    fig.savefig("full_posterior_raw.pdf", bbox_inches="tight")
# Out:
# /mnt/qb/work/macke/mgloeckler90/miniconda3/envs/snvi/lib/python3.9/site-packages/sbi/utils/plot.py:188: UserWarning: Importing `pairplot` from `sbi.utils` is deprecated since sbi v0.15.0. Instead, use `from sbi.analysis import pairplot`.
#   warn(
# /mnt/qb/work/macke/mgloeckler90/miniconda3/envs/snvi/lib/python3.9/site-packages/sbi/utils/plot.py:205: UserWarning: You passed an argument `fig_size`. Since sbi v0.15.0, the argument should be called `figsize`. In future versions, `fig_size` will no longer be supported.
#   warn(

# %%
limits = list(zip(list(task.get_prior_dist().support.base_constraint.lower_bound), list(task.get_prior_dist().support.base_constraint.upper_bound)))
cond_idx = 42

# %%
# with mpl.rc_context(fname='../../.matplotlibrc'):
#     mpl.rc('font',family='DejaVu Sans')
#     fig = conditional_pairplot(posterior, samples[cond_idx], limits, labels=task.names, figsize=(40,40), diag="kde", points=[samples[cond_idx]], points_colors=["darkgreen"], points_offdiag={"markersize":10})
#     fig[0].savefig("full_conditonal_pairplot_raw.pdf")

# %%
import torch
import matplotlib as mpl
predictives = xs_predictives
post_pred_valid = predictives[(predictives!=-99).all(1)]

# %%
names = ["AB/PD CaS       $\\;\\;$", "AB/PD Ca       $\\;\\;$", "Syn.AB-LP       $\\;\\;$", "Syn.PD-LP       $\\;\\;$"]

# %%
thetas, xs = task.get_precomputed_dataset()
xs = xs[:1000000]
prior_pred_valid = xs[(xs!=-99).all(1)]

xs_mean = prior_pred_valid.mean(0)
xs_std = prior_pred_valid.std(0)
# z score the x
prior_pred_valid_zscored = (prior_pred_valid - xs_mean)/xs_std
post_pred_valid_zscored = (post_pred_valid - xs_mean)/xs_std
x_o_zscored = (task.get_observation(2)-xs_mean)/xs_std

median_dist_prior = torch.sqrt(torch.sum((prior_pred_valid_zscored - x_o_zscored)**2, 1).median())
median_dist_posterior = torch.sqrt(torch.sum((post_pred_valid_zscored - x_o_zscored)**2, 1).median())
# Out:
# /mnt/qb/work/macke/mgloeckler90/SNVI_paper/snlvibm/sbivibm/sbivibm/tasks/pyloric_stg/pyloric_stg.py:204: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/TensorAdvancedIndexing.cpp:1582.)
#   xs[np.isnan(xs)] = self.nan_replace

# %%
fontsize=9

# %%
import matplotlib as mpl
import seaborn as sns
idx = [2,4, 24, 25]
small_samples = samples[:, idx]
sns.set(font="DejaVu Sans")
with mpl.rc_context(fname='../../.matplotlibrc'):
    mpl.rc('font',family='DejaVu Sans')
    m = MEAN[idx]
    mode = MAP[idx]
    fig1, axes = pairplot(small_samples, figsize=(2.2,2.2), labels=names,diag="kde", points_offdiag={"markersize":4}, cmap="viridis", points=[m,mode], points_colors=["black", "C3"])
#     ]
    for i in range(2):
        axes[i,i].set_xticks((np.round(limits[idx[i]][0],2), np.round(limits[idx[i]][1],2)))
    for i in range(2,4):
        axes[i,i].set_xticks((np.round(limits[idx[i]][0],2), np.round(limits[idx[i]][1],2)))
        axes[i,i].set_xticklabels((r"$10^{-2}$", r"$10^{3}$"))
        
#     #axes[1,0].scatter(m[1], m[0], color="black")
#     axes[-1,0].scatter(mode[0], mode[-1],color="red")
    fig1.savefig("small_posterior_raw.pdf", transparent=True)
# Out:
# /mnt/qb/work/macke/mgloeckler90/miniconda3/envs/snvi/lib/python3.9/site-packages/sbi/utils/plot.py:188: UserWarning: Importing `pairplot` from `sbi.utils` is deprecated since sbi v0.15.0. Instead, use `from sbi.analysis import pairplot`.
#   warn(

# %%
fig1

# %%
cond_idx = 42

# %%
class SmallPost():
    def log_prob(self,y):
        N = len(y)
        x = samples[cond_idx].clone().repeat(N,1)
        x[:,idx] = y
        return posterior.log_prob(x)
p = SmallPost()  

limits_small = [limits[i] for i in idx]
with mpl.rc_context(fname='../../.matplotlibrc'):
    mpl.rc('font',family='DejaVu Sans')
    fig2, axes = conditional_pairplot(p, samples[cond_idx][idx], limits_small, labels=names, tick_labelpad=1,labelpad=1, fontsize=20, figsize=(2.2,2.2), points_offdiag={"markersize":4}, points=[samples[cond_idx][idx]], points_colors=["darkgreen"])
    for i in range(2):
        axes[i,i].set_xticks((np.round(limits[idx[i]][0],2), np.round(limits[idx[i]][1],2)))
    for i in range(2,4):
        axes[i,i].set_xticks((np.round(limits[idx[i]][0],2),np.round(limits[idx[i]][1],2)))
        axes[i,i].set_xticklabels((r"$10^{-2}$", r"$10^{3}$"))
    fig2.savefig("small_conditional_pairplot_raw.pdf", transparent=True)
fig2
# Out:
# /mnt/qb/work/macke/mgloeckler90/miniconda3/envs/snvi/lib/python3.9/site-packages/sbi/utils/plot.py:440: UserWarning: Importing `conditional_pairplot` from `sbi.utils` is deprecated since sbi v0.15.0. Instead, use `from sbi.analysis import conditional_pairplot`.
#   warn(

# %%
MCMC_time = 47340/3600
VI_time = 528/3600
valid_rate_prior = int(np.round(len(prior_pred_valid)/len(xs), 2)*100)
valid_rate_posterior = int(np.round(len(post_pred_valid)/len(predictives),2)*100)

# %%
valid_rate_prior
# Out:
# 1

# %%
valid_rate_posterior
# Out:
# 86

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
with mpl.rc_context(fname='../../.matplotlibrc'):
    fig, axes = plt.subplots(2,1,figsize=(2.3,2.3))
    axes[0].barh([0.15],[median_dist_posterior], color="midnightblue", height=0.15)
    axes[0].barh([0.35],[median_dist_prior], color="royalblue", height=0.15)
    #axes[0].legend(["Prior", "Posterior"], fontsize=10)
    axes[0].set_xlabel("Median distance $||x-x_o||_2$", fontsize=fontsize, fontname="DejaVu Sans")
    axes[0].set_yticklabels([ "Post.", "Prior"], fontsize=fontsize, fontname="DejaVu Sans")
    #axes[0].set_xticklabels([ 0,1,2,3], fontsize=11, fontname="DejaVu Sans")
    axes[0].set_yticks([0.15,0.35])
    axes[0].set_ylim(0,0.5)
    axes[0].set_xlim(0,3)
    axes[0].set_xticks([0,3])
    axes[0].set_xticklabels([0,3], fontsize=fontsize, fontname="DejaVu Sans")
    axes[0].text(2.2, 0.31, fr"$\ \ ${valid_rate_prior}% 'valid'", fontsize=fontsize, fontname="DejaVu Sans")
    axes[0].text(2.2, 0.11, f"{valid_rate_posterior}% 'valid'", fontsize=fontsize, fontname="DejaVu Sans")
    
    axes[1].set_xlabel("Time [h]", fontsize=fontsize, fontname="DejaVu Sans")
    axes[1].barh([0.15,0.35], [MCMC_time, VI_time], color=(0.15,0.15,0.2), height=0.15)
    axes[1].set_yticks([0.15,0.35])
    axes[1].set_ylim(0,0.5)
    axes[1].set_xlim(0,13)
    axes[1].set_xticks([0,13])
    axes[1].set_xticklabels([0,13], fontsize=fontsize, fontname="DejaVu Sans")
    axes[1].set_yticklabels(["MCMC \n (100 chains)", "VI fKL"])
    axes[1].set_yticklabels(["MCMC", "VI fKL"], fontsize=fontsize, fontname="DejaVu Sans")
    fig.subplots_adjust(hspace=0.9)
fig.savefig("predictive_fig_raw.pdf", transparent=True, bbox_inches="tight")
fig
# Out:
# /tmp/ipykernel_11623/99520864.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_yticklabels([ "Post.", "Prior"], fontsize=fontsize, fontname="DejaVu Sans")

# %%
task2 = Pyloric(summary=None)
task = Pyloric()
simulator = task2.get_simulator(sim_type="sequential", seed=0)
simulator_stats = task.get_simulator(sim_type="sequential", seed=0)

# %%
x_pred = simulator_stats(samples[:50])

# %%
valid_idx = (x_pred != 0).all(1)
x_pred_valid = task2.unflatten_data(simulator(samples[:50][valid_idx]))

# %%
predictives_to_plot = 3

# %%
x_map = task2.unflatten_data(simulator(MAP))
x_mean = task2.unflatten_data(simulator(MEAN))

# %%
import numpy as np
npz = np.load('../../trace_data_845_082_0044.npz')
t = npz['t']
PD_spikes = npz['PD_spikes']
LP_spikes = npz['LP_spikes']
PY_spikes = npz['PY_spikes']
pdn = npz['pdn']
lpn = npz['lpn']
pyn = npz['pyn']
start_index = 219500 + 2100
end_index   = 246500 + 2100  # 32000
height_offset = 200
shown_t = t[end_index] - t[start_index]
time_len = shown_t / 0.025 * 1000
dt = t[1] - t[0]

# %%
t = t-t[start_index]

# %%
x_mean = x_mean / x_mean.max() + 1
x_map = x_map / x_map.max() + 1

# %%
t_sim = np.linspace(t[start_index], t[end_index], 161000-54000)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import seaborn as sns
with mpl.rc_context(fname='../../.matplotlibrc'):
    mpl.rc('font',family='DejaVu Sans')
    fig = plt.figure(figsize=(2,1.75))
    plt.plot(t[start_index:end_index], 0.8+pdn[start_index:end_index]*0.0015, c="k", lw=0.8)
    plt.plot(t[start_index:end_index], 0.6+lpn[start_index:end_index]*0.075, c="k", lw=0.8)
    plt.plot(t[start_index:end_index], 0.33+pyn[start_index:end_index]*0.0035, c="k", lw=0.8)
    
    linew = 0.2
    headl = 0.06
    headw = 0.02
    linelen = 0.02
    circlefact = 0.2
    
    # period arrow
    height1 = 0.92
    plt.arrow(t[start_index]+0.6, height1, 1.15, 0,  shape='full', head_width=headw, head_length=headl, length_includes_head=True, color='k', lw=linew)
    plt.arrow(t[start_index]+1.75, height1, -1.15, 0,  shape='full', head_width=headw, head_length=headl, length_includes_head=True, color='k', lw=linew)
    plt.plot([t[start_index]+0.6, t[start_index]+0.6], [height1-linelen,height1+linelen], c='k', lw=linew*2.5)
    plt.plot([t[start_index]+1.75, t[start_index]+1.75], [height1-linelen,height1+linelen], c='k', lw=linew*2.5)
    #patch =mp.Ellipse((t[start_index]+1.2, 3.65), 0.2*circlefact,0.6*circlefact, color='lightgray')
    #ax.add_patch(patch)
    
    # delay arrow
    height2 = 0.67
    plt.arrow(t[start_index]+0.6, height2, 0.48, 0,  shape='full', head_width=headw, head_length=headl, length_includes_head=True, color='k', lw=linew)
    plt.arrow(t[start_index]+1.08, height2, -0.48, 0,  shape='full', head_width=headw, head_length=headl, length_includes_head=True, color='k', lw=linew)
    plt.plot([t[start_index]+0.6, t[start_index]+0.6], [height2-linelen,height2+linelen], c='k', lw=linew*2.5)
    plt.plot([t[start_index]+1.08, t[start_index]+1.08], [height2-linelen,height2+linelen], c='k', lw=linew*2.5)
    #patch =mp.Ellipse((t[start_index]+0.94, 2.1), 0.2*circlefact,0.6*circlefact, color='lightgray')
    #ax.add_patch(patch)
    
    # gap arrow
    plt.arrow(t[start_index]+1.98, height2, 0.27, 0,  shape='full', head_width=headw, head_length=headl, length_includes_head=True, color='k', lw=linew)
    plt.arrow(t[start_index]+2.25, height2, -0.27, 0,  shape='full', head_width=headw, head_length=headl, length_includes_head=True, color='k', lw=linew)
    plt.plot([t[start_index]+1.98, t[start_index]+1.98], [height2-linelen,height2+linelen], c='k', lw=linew*2.5)
    plt.plot([t[start_index]+2.25, t[start_index]+2.25], [height2-linelen,height2+linelen], c='k', lw=linew*2.5)
    #patch =mp.Ellipse((t[start_index]+2.1, 2.1), 0.2*circlefact,0.6*circlefact, color='lightgray')
    #ax.add_patch(patch)
    
    # duration arrow
    height4 = 0.43
    plt.arrow(t[start_index]+1.33, height4, 0.43, 0,  shape='full', head_width=headw, head_length=headl, length_includes_head=True, color='k', lw=linew)
    plt.arrow(t[start_index]+1.76, height4, -0.43, 0,  shape='full', head_width=headw, head_length=headl, length_includes_head=True, color='k', lw=linew)
    plt.plot([t[start_index]+1.33, t[start_index]+1.33], [height4-linelen,height4+linelen], c='k', lw=linew*2.5)
    plt.plot([t[start_index]+1.76, t[start_index]+1.76], [height4-linelen,height4+linelen], c='k', lw=linew*2.5)
    #patch =mp.Ellipse((t[start_index]+1.55, 0.9), radius=0.2, color='lightgray')
    #ax.add_patch(patch)
    
    
    #plt.xticks([0., 0.5, 1., 1.5, 2., 2.5])
    plt.yticks([0.33,0.58,0.81], labels=["PY","LP", "AB\nPD"], fontsize=fontsize)
    plt.xticks(fontsize=fontsize)
    plt.ylim(0.2,1.)
    plt.xlabel("Time [s]", fontsize=fontsize)
    plt.title("Empirical observation", fontsize=fontsize)
    sns.despine(fig, left=True)
    ax = plt.gca()
    ax.tick_params(axis="y",length=0)
    fig.savefig("traces_empirical.pdf", transparent=True, bbox_inches="tight")
fig

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import seaborn as sns
plt.rcParams['svg.fonttype'] = 'path'
with mpl.rc_context(fname='../../.matplotlibrc'):
    mpl.rc('font',family='DejaVu Sans')
    fig = plt.figure(figsize=(2.25,2))
    plt.plot(t_sim, 0.75+x_mean[0,0][55000:162000]*0.07, c="k", lw=0.8)
    plt.plot(t_sim, 0.52+x_mean[0,1][55000:162000]*0.07, c="k", lw=0.8)
    plt.plot(t_sim, 0.28+x_mean[0,2][55000:162000]*0.07, c="k", lw=0.8)
    
    plt.plot(t_sim, 0.75+x_map[0,0][55000:162000]*0.07, c="C3", lw=0.8)
    plt.plot(t_sim, 0.52+x_map[0,1][55000:162000]*0.07, c="C3", lw=0.8)
    plt.plot(t_sim, 0.28+x_map[0,2][55000:162000]*0.07, c="C3", lw=0.8)
    
    line1 = mlines.Line2D([0,1],[0,1], color="black", label="Mean")
    line2 = mlines.Line2D([0,1],[0,1], color="C3", label="MAP")
    plt.legend(handles=[line1,line2], ncol=2, fontsize=fontsize, handlelength=1)
    plt.xticks(fontsize=10)
    plt.yticks([0.33,0.58,0.81], labels=["PY","LP", "AB\nPD"], fontsize=fontsize, fontname="DejaVu Sans")
    plt.ylim(0.2,1.1)
    plt.xticks(fontsize=fontsize)
    plt.xlabel("Time [s]", fontsize=fontsize, fontname="DejaVu Sans")
    plt.title("Posterior mean/map", color="white", fontsize=fontsize, fontname="DejaVu Sans")
    sns.despine(fig, left=True)
    ax = plt.gca()
    ax.tick_params(axis="y",length=0)
    fig.savefig("traces_map_raw.pdf", transparent=True,bbox_inches="tight")
fig

# %%
# Some dont look pretty because internal spikes collapse... -> Due to summary statistics! Not inference!

# %%
idx = [7,8,9]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
with mpl.rc_context(fname='../../.matplotlibrc'):
    mpl.rc('font',family='DejaVu Sans')
    fig = plt.figure(figsize=(2.25,2.05))
    colors = ["seagreen", "brown", "midnightblue"]
    for i in range(predictives_to_plot):
        x = x_pred_valid[idx[i],:] 
        x = x / x.max() + 1
        plt.plot(t_sim, 0.75+x[0][55000:162000]*0.07, c=colors[i], lw=0.8, alpha=0.8)
        plt.plot(t_sim, 0.52+x[1][55000:162000]*0.07, c=colors[i], lw=0.8, alpha=0.8)
        plt.plot(t_sim, 0.28+x[2][55000:162000]*0.07, c=colors[i], lw=0.8, alpha=0.8)
    plt.xticks(fontsize=10)
    plt.yticks([0.33,0.58,0.81], labels=["PY","LP", "AB\nPD"], fontsize=fontsize)
    plt.ylim(0.2,1.1)
    plt.xticks(fontsize=fontsize)
    plt.xlabel("Time [s]", fontsize=fontsize)
    plt.title("Random samples", fontsize=fontsize, y=0.8)
    plt.yticks([])
    sns.despine(fig, left=True)
    ax = plt.gca()
    ax.tick_params(axis="y",length=0)
    fig.savefig("traces_samples_raw.pdf", transparent=True, bbox_inches="tight")

# %%
fig
